# %% [markdown]
# <a href="https://colab.research.google.com/github/prajwal714/Machine-Learning-Lab/blob/master/Polynomial_curve_fitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math  
import numpy as np
x=[]
y=[]
import random 
def Rand( num): 
    res = [] 
    for j in range(num): 
        res.append(np.random.rand()) 
    return res 
noise=Rand(100)

x = np.linspace(0, 3*math.pi, 100)
for i in range(len(x)):
  y.append(math.sin(x[i])+noise[i])

# %%
#linear curve
import matplotlib.pyplot as plt 
z = np.polyfit(np.array(x), np.array(y), 1)
f = np.poly1d(z)
x_new = np.linspace(x[0], x[-1], 100)
y_new = f(x_new)
 
x1 =x 
y1 =y
plt.plot(x1, y1, label = "line 1") 
  
x2 =x_new
y2 =y_new
plt.plot(x2, y2, label = "line 2") 
  
plt.xlabel('x - axis') 
plt.ylabel('y - axis') 
plt.title('Two lines on same graph!') 
  
plt.legend() 
  
plt.show() 

from sklearn.metrics import mean_squared_error 
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(y_new,y)
# Out:
# 0.5247774239179622

# %%
#quadratic curve
import matplotlib.pyplot as plt 
z = np.polyfit(np.array(x), np.array(y), 2)
f = np.poly1d(z)
x_new = np.linspace(x[0], x[-1], 100)
y_new = f(x_new)
 
x1 =x 
y1 =y
plt.plot(x1, y1, label = "line 1") 
  
x2 =x_new
y2 =y_new
plt.plot(x2, y2, label = "line 2") 
  
plt.xlabel('x - axis') 
plt.ylabel('y - axis') 
plt.title('Two lines on same graph!') 
  
plt.legend() 
  
plt.show() 

from sklearn.metrics import mean_squared_error 
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(y_new,y)
# Out:
# 0.370686068947632

# %%
#cubic function
import matplotlib.pyplot as plt 
z = np.polyfit(np.array(x), np.array(y), 3)
f = np.poly1d(z)
x_new = np.linspace(x[0], x[-1], 100)
y_new = f(x_new)
 
x1 =x 
y1 =y
plt.plot(x1, y1, label = "line 1") 
  
x2 =x_new
y2 =y_new
plt.plot(x2, y2, label = "line 2") 
  
plt.xlabel('x - axis') 
plt.ylabel('y - axis') 
plt.title('Two lines on same graph!') 
  
plt.legend() 
  
plt.show() 

from sklearn.metrics import mean_squared_error 
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(y_new,y)
# Out:
# 1.2954664618372542

# %%
#power four function
import matplotlib.pyplot as plt 
z = np.polyfit(np.array(x), np.array(y), 200)
f = np.poly1d(z)
x_new = np.linspace(x[0], x[-1], 100)
y_new = f(x_new)
 
x1 =x 
y1 =y
plt.plot(x1, y1, label = "line 1") 
  
x2 =x_new
y2 =y_new
plt.plot(x2, y2, label = "line 2") 
  
plt.xlabel('x - axis') 
plt.ylabel('y - axis') 
plt.title('Two lines on same graph!') 
  
plt.legend() 
  
plt.show() 

from sklearn.metrics import mean_squared_error 
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(y_new,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/polynomial.py:629: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 0.8159418404474666

# %%
from sklearn.metrics import mean_squared_error 
# Calculation of Mean Squared Error (MSE) 
mean_squared_error(y_new,y)
# Out:
# 0.06800220336177454

# %%
p=[]
q=[]
for i in range(200):
  #power four function
  import matplotlib.pyplot as plt 
  z = np.polyfit(np.array(x), np.array(y), i+1)
  f = np.poly1d(z)
  x_new = np.linspace(x[0], x[-1], 100)
  y_new = f(x_new)
  p.append(i+1)
  q.append(mean_squared_error(y_new,y)) 

plt.plot(p, q, 'bx-') 
plt.xlabel('Values of K') 
plt.ylabel('Distortion') 
plt.title('The Elbow Method using Distortion') 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...
